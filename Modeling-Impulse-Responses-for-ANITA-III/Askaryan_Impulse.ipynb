# %%
import numpy as  np
import matplotlib.pyplot as plt
import numpy.fft as fft
# %matplotlib inline

# %%
A=['JEshower_45.8.dat','JEshower_48.3.dat','JEshower_50.8.dat','JEshower_53.3.dat','JEshower_55.8.dat']




myarray = np.loadtxt('JEshower_53.3.dat')
    
#waveforms=[myarray[80],myarray[74],myarray[68],myarray[86],myarray[92]]
waveforms=[myarray[0],myarray[40],myarray[80],myarray[120],myarray[159]]
 
#print(len(myarray[80]))
time=np.linspace(0,5,50)

#print(len(time))

for i in range(len(waveforms)):
    
    #plt.figure()
    plt.plot(time,waveforms[i])
    plt.xlabel('Time (ns)')
plt.ylabel('Electric Field (V/m)') 
    


N=len(time);
dt=0.01

f = fft.fft(myarray[40])
fshift = fft.fftshift(f)


freq = fft.fftfreq(N, dt)
plt.figure()
plt.loglog(fft.fftshift(freq), 1000*abs(fshift))
plt.xlim(0)
#plt.ylim(10**(-13))
    
N=len(time);
dt=0.01

f = fft.fft(myarray[80])
fshift = fft.fftshift(f)


freq = fft.fftfreq(N, dt)
plt.figure()
plt.loglog(fft.fftshift(freq), 1000*abs(fshift))
plt.xlim(0)



N=len(time);
dt=0.01

f = fft.fft(myarray[120])
fshift = fft.fftshift(f)


freq = fft.fftfreq(N, dt)
plt.figure()
plt.loglog(fft.fftshift(freq), 1000*abs(fshift))
plt.xlim(0)
# Out:
# (2.0, 56.26674594260389)

# %%
A=['JEshower_45.8.dat','JEshower_48.3.dat','JEshower_50.8.dat','JEshower_53.3.dat','JEshower_55.8.dat']




myarray = np.loadtxt('JEshower_53.3.dat')
    
#myarray=myarray[70:90]
 
time=np.linspace(10,50,50)
plt.plot(myarray[10])
plt.figure()
for i in range(len(myarray)):
    

    plt.plot(myarray[i])
    

    

plt.xlabel('Time (ns)')
plt.ylabel('Electric Field (V/m)')

# %%
A=['JEshower_45.8.dat','JEshower_48.3.dat','JEshower_50.8.dat','JEshower_53.3.dat','JEshower_55.8.dat']



'''
myarray = np.loadtxt('JEshower_53.3.dat')
    
print myarray
 
for i in range(len(myarray)):
    
    plt.plot(myarray[i])
    

plt.xlabel('Time (ns)')
plt.ylabel('Electric Field (V/m)') 
'''

Impulse = np.loadtxt('JEshower_53.3.dat')


plt.grid(True)
plt.plot(Impulse[80])
plt.grid
plt.title('Askaryan Radiation',fontsize=22)
plt.xlabel('Time (ns)',fontsize=20)
plt.ylabel('Amplitude (V)',fontsize=20)

#time=range(50);
time=np.arange(0,5,.1)

f = fft.fft(Impulse[80])
fshift = fft.fftshift(f)

N=len(time)
dt=time[2]-time[1]



freq = fft.fftfreq(N, dt)


plt.figure(2)
plt.loglog(fft.fftshift(freq), abs(fshift*fshift))
plt.xlim(0)

indx = abs(fshift*fshift).tolist().index(max(abs(fshift*fshift)))

# %%
f = fft.fft(Impulse[80])
fshift = fft.fftshift(f)

N=len(time)
dt=time[2]-time[1]



freq = fft.fftfreq(N, dt)

plt.loglog(fft.fftshift(freq), abs(fshift*fshift))
plt.xlim(0)
# Out:
# (0.20000000000000001, 5.6266745942603906)

# %%
Impulse = np.loadtxt('shower_55.8.dat')

A=[Impulse[400],Impulse[0]]

time=np.arange(0,.00491,.00001)



for i in range(2):
    
    plt.plot(time,A[i])








'''
for i in range(2):
    f = fft.fft(A[i])
    fshift = fft.fftshift(f)

    N=len(time)
    dt=time[2]-time[1]



    freq = fft.fftfreq(N, dt)

    plt.loglog(fft.fftshift(freq), abs(fshift*fshift))
    plt.xlim(0)
    
    #print  abs(fshift*fshift)
 '''

f = fft.fft(Impulse[0])
fshift = fft.fftshift(f)

N=len(time)
dt=time[2]-time[1]

plt.figure(2)

freq = fft.fftfreq(N, dt)


fdom1=fft.fftshift(freq)
fcodom1=abs(fshift*fshift)

plt.loglog(fdom1, fcodom1)
plt.xlim(0)
# Out:
# (203.66598778004072, 65696.600360975455)

# %%
Impulse = np.loadtxt('shower2_55.8.dat')

A=[Impulse[400],Impulse[0]]

time=np.arange(0,.00491,.00001)






plt.plot(time,Impulse[0])



A=[Impulse[400],Impulse[0]]
'''
for i in range(2):
    f = fft.fft(A[i])
    fshift = fft.fftshift(f)

    N=len(time)
    dt=time[2]-time[1]



    freq = fft.fftfreq(N, dt)

    plt.loglog(fft.fftshift(freq), abs(fshift*fshift))
    plt.xlim(0)
    
    #print  abs(fshift*fshift)
 '''

f = fft.fft(Impulse[0])
fshift = fft.fftshift(f)

N=len(time)
dt=time[2]-time[1]



freq = fft.fftfreq(N, dt)


plt.figure(2)

fdom2=fft.fftshift(freq)
fcodom2=abs(fshift*fshift)

plt.loglog(fdom2, fcodom2)
plt.xlim(0)
# Out:
# (203.66598778004072, 65696.600360975455)

# %%
Impulse = np.loadtxt('shower_1TeV_55.8.dat')

A=[Impulse[400],Impulse[0]]

time=np.arange(0,.00491,.00001)






plt.plot(time,Impulse[399])



A=[Impulse[400],Impulse[0]]
'''
for i in range(2):
    f = fft.fft(A[i])
    fshift = fft.fftshift(f)

    N=len(time)
    dt=time[2]-time[1]



    freq = fft.fftfreq(N, dt)

    plt.loglog(fft.fftshift(freq), abs(fshift*fshift))
    plt.xlim(0)
    
    #print  abs(fshift*fshift)
 '''

f = fft.fft(Impulse[399])
fshift = fft.fftshift(f)

N=len(time)
dt=time[2]-time[1]



freq = fft.fftfreq(N, dt)


plt.figure(2)

fdom2=fft.fftshift(freq)
fcodom2=abs(fshift*fshift)

plt.loglog(fdom2, fcodom2)
#plt.xlim(2e8,1.2e9)

plt.title('1 TeV',fontsize=14)
plt.xlabel('Frequency (Hz)',fontsize=12)
plt.ylabel('Power',fontsize=12)

# %%
Impulse = np.loadtxt('shower_1TeV_55.8.dat')

A=[Impulse[400],Impulse[0]]

#time=np.arange(0,4.91,.01)
time=np.arange(0,2.455,.005)






plt.plot(time,Impulse[399])



A=[Impulse[400],Impulse[0]]


f = fft.fft(Impulse[399])
fshift = fft.fftshift(f)

N=len(time)
dt=time[2]-time[1]
plt.grid(True)


freq = fft.fftfreq(N, dt)


plt.figure(2)

fdom2=fft.fftshift(freq)
fcodom2=abs(fshift*fshift)

plt.loglog(fdom2, fcodom2)
#plt.xlim(0.2,1.2)


#print(fcodom2)

plt.title('1 TeV',fontsize=14)
plt.xlabel('Frequency (GHz)',fontsize=12)
plt.ylabel('Power',fontsize=12)

# %%
Impulse = np.loadtxt('shower_1TeV_55.8.dat')



#time=np.arange(0,4.91,.01)
time=np.arange(0,0.01*491,.01)


plt.plot(time,Impulse[399])


f = fft.fft(Impulse[399])
fshift = fft.fftshift(f)

N=len(time)
dt=time[2]-time[1]
plt.grid(True)
print(len(Impulse[399]))

freq = fft.fftfreq(N, dt)


plt.figure(2)

fdom2=fft.fftshift(freq)
fcodom2=abs(fshift)

plt.loglog(fdom2, fcodom2)
#plt.xlim(0.2,1.2)


#print(fcodom2)

plt.title('1 TeV',fontsize=14)
plt.xlabel('Frequency (GHz)',fontsize=12)
plt.ylabel('Power',fontsize=12)
# Out:
# 491

# %%
title=['$\Theta_c-10^{\circ}$','$\Theta_c-5^{\circ}$','\Theta_c +$0^{\circ}$','\Theta_c +$5^{\circ}$','\Theta_c +$10^{\circ}$']
f=fdom2
A=[45.8,50.8,55.8,60.8,65.8]

for i in range(len(A)-2):
    theta=A[i]*np.pi/180;
    theta_c = np.arccos(1/1.78); #Radians


#E0=1e9#*(1+np.sin(theta/theta_c))
    E0=100


    Ein=fcodom2
#Ein=1e7

    nu0 = 0.5; #GHz
    E_LPM = 2e15/1e9; #GeV
    gamma = 0.3;
#if(E0<1.0e6):
#delta_theta = 2.7*(nu0/f)*E0**(-0.03);
#delta_theta = delta_theta*np.pi/180.0;
#else:

#delta_theta = 2.7*(nu0/f)*((E_LPM)/(0.14*E0+E_LPM))**gamma;
#delta_theta = delta_theta*np.pi/180.0;

    delta_theta=2.4*np.pi/180 *(nu0/fdom2)


#Eout = np.sin(theta)/np.sin(theta_c)*Ein*np.exp(-np.log10(2)*(theta-theta_c)**2./(delta_theta)**2);


    Eout=1.1*10**(-7)*E0*(fdom2/nu0)*1/(1+(fdom2/nu0)**2)*np.exp(-0.5*((theta-theta_c)/delta_theta)**2)
#Eout=E0*np.exp(-0.5*((theta-theta_c)/delta_theta)**2)
    df=fdom2[1]-fdom2[0]
    df*=1e3
    R=1000
   # plt.figure()
    
#plt.semilogx(f,Eout)
    plt.loglog(f,R*Eout/df,label=title[i])
    
#plt.plot(f,Eout)
    plt.xlim(0,10)
    plt.ylim(10e-7,10e-5)
plt.legend(loc='best')
# Out:
# /home/donald/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:28: RuntimeWarning: divide by zero encountered in true_divide
